# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading data

# %%
data = np.loadtxt('1_Day_FRB_Sky_on_Earth.txt', skiprows=7)

# %%
data
# Out:
# array([[ 0.000000e+00,  3.012800e+02,  4.877000e+01, ...,  2.600000e+41,
#          1.100000e-03,  1.800000e-02],
#        [ 1.000000e+00,  7.873000e+01, -4.215000e+01, ...,  9.000000e+41,
#          6.800000e-03,  2.000000e-02],
#        [ 2.000000e+00,  2.423100e+02,  3.540000e+00, ...,  8.900000e+41,
#          4.100000e-03,  4.100000e-02],
#        ...,
#        [ 3.507299e+06,  3.064000e+02,  2.536000e+01, ...,  1.700000e+41,
#          1.200000e-02,  1.000000e-02],
#        [ 3.507300e+06,  8.075000e+01, -1.450000e+01, ...,  1.200000e+41,
#          1.800000e-03,  1.200000e-02],
#        [ 3.507301e+06,  3.720000e+00,  4.369000e+01, ...,  5.500000e+41,
#          7.600000e-03,  2.400000e-02]])

# %% [markdown]
# # Converting to DataFrame

# %%
params = ['ra', 'dec', 'gl', 'gb', 'dist_co', 'z', 'dm', 'dm_mw', 'dm_host', 'dm_igm', \
          'w_int', 'w_arr', 'w_eff', 't_dm', 't_scat', 'lum_bol', 's_peak', 'fluence']
df = pd.DataFrame(data[:, 1:], index=data[:, 0].astype(int), columns=params)

# %%
df
# Out:
#              ra    dec      gl     gb  dist_co      z       dm   dm_mw  \
# 0        301.28  48.77   84.21   9.78     2.93  0.823   932.18  133.02
# 1         78.73 -42.15 -112.03 -36.08     2.34  0.622  1200.91   43.95
# 2        242.31   3.54   15.47  38.33     2.83  0.787  1233.05   41.74
# 3        304.59 -28.29   15.10 -29.36     2.50  0.675   797.59   68.54
# 4         56.46 -26.45 -137.14 -52.38     2.61  0.711   400.71   34.25
# ...         ...    ...     ...    ...      ...    ...      ...     ...
# 3507297    6.56 -14.46   93.38 -75.50     2.70  0.742  1928.97   29.56
# 3507298  221.68  13.97   12.37  61.12     2.49  0.670   932.51   23.73
# 3507299  306.40  25.36   66.66  -6.30     0.52  0.121   932.98  229.37
# 3507300   80.75 -14.50 -142.99 -27.11     1.97  0.507   825.60   54.62
# 3507301    3.72  43.69  116.03 -18.54     1.99  0.513  1418.59   75.74
#
#          dm_host  dm_igm  w_int  w_arr  w_eff   t_dm  t_scat       lum_bol  \
# ...
