# %%
import numpy as np
import re
import pandas as pd
import matplotlib.pyplot as plt
from frbpoppy.tns import TNS, get_chimefrb_catalog1

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading catalog

# %%
tns = TNS(tns_name="YOUR_NAME", tns_id=YOUR_ID, repeaters=False, mute=True, update=False).df

# %%
chime_catalog_1 = get_chimefrb_catalog1(repeater=False)

# %% [markdown]
# # Fig.1

# %%
fig = plt.figure(figsize=(4,3), dpi=300)
bins1 = np.linspace(100, 3050, 60)
bins2 = np.linspace(100, 2600, 51)

mask = (tns.telescope =='chime')

plt.hist(tns.dm, bins=bins1, label='All', rwidth=0.95, color='#7985B3')
plt.hist(chime_catalog_1.dm, bins=bins1, label='CHIME/FRB', rwidth=0.95, color='#F0B47C')
plt.hist(tns[~mask].dm, bins=bins2, label='Other telescopes', rwidth=0.95, color='#BE7A9A')
plt.xlabel('DM (pc cm$^{-3}$)', fontsize=12)
plt.ylabel('Counts per bin')
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.legend(fontsize='small')
plt.tight_layout()
plt.savefig('dm_distribution.pdf', transparent=True)

# %% [markdown]
# # Fig.2

# %%
fig = plt.figure(figsize=(4,3), dpi=300)
bins1 = np.linspace(0, 420, 85)
bins2 = np.linspace(0, 140, 29)

plt.hist(tns.snr, bins=bins1, density=False, label='All', rwidth=0.95, color='#7985B3')
plt.hist(chime_catalog_1.snr, bins=bins2, density=False, label='CHIME/FRB', rwidth=0.95, color='#F0B47C')
plt.hist(tns[~mask].snr, bins=bins1, density=False, label='Other telescopes', rwidth=0.95, color='#BE7A9A')
plt.xlabel('S/N', fontsize=12)
plt.ylabel('Counts per bin')
plt.yscale('log')
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.legend(fontsize='small')
plt.tight_layout()
plt.savefig('snr_distribution.pdf', transparent=True)
